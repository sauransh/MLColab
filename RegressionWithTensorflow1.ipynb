# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = '/content/sample_data/kc_house_data.csv'
df = pd.read_csv(file)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.head(2)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
#
#    sqft_lot15
# 0        5650
# 1        7639
#
# [2 rows x 21 columns]

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['price'])
# Out:
# <ipython-input-32-72629807b4c8>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.countplot(df['bedrooms'])
# Out:
# <Axes: ylabel='count'>

# %%
df.corr()['price'].sort_values()
# Out:
# <ipython-input-34-78b4f396fb2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['price'].sort_values()
# zipcode         -0.053203
# id              -0.016762
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
sns.scatterplot(x='price',y='sqft_living',data=df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
sns.boxplot(x='bedrooms',y='price',data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price',palette='RdYlGn')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
len(df)*0.01
# Out:
# 216.13

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 8092   1924059029  20140617T000000  4668000.0         5       6.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 8638   3835500195  20140618T000000  4489000.0         4       3.00
# 12370  6065300370  20150506T000000  4208000.0         5       6.00
# 4149   6447300265  20141014T000000  4000000.0         4       5.50
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# ...

# %%
no_top_1_prec = df.sort_values('price',ascending=False).iloc[216:]

# %%
no_top_1_prec.head()
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 3281   8964800025  20150226T000000  1965000.0         5       3.75
# 12577  2806300065  20150422T000000  1960000.0         4       4.00
# 12283  1923000260  20141015T000000  1959000.0         5       4.50
# 1152   4055701200  20150421T000000  1955000.0         4       2.75
# 9175   3124059023  20150213T000000  1955000.0         3       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 3281          3940     13738     1.5           0     3  ...      9
# 12577         4430     31353     2.0           0     0  ...     12
# 12283         6200     23373     3.0           0     1  ...     11
# 1152          3120      7898     1.0           1     4  ...      8
# 9175          3330     12566     1.0           1     4  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 3281         3940              0      1951             0    98004  47.6203
# ...

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=no_top_1_prec,hue='price',palette='RdYlGn')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].apply(lambda date:date.year)

# %%
df['month'] = df['date'].apply(lambda date:date.month)

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  year  \
# ...

# %%
df.drop('date',axis=1,inplace=True)

# %%
df.drop('zipcode',axis=1)
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0      13126
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
sns.boxplot(x='month',y='price',data = df)
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
sns.boxplot(x='year',y='price',data=df)
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# <Axes: xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
X = df.drop('price',axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-869e3723d493> in <cell line: 1>()
# ----> 1 X_test = scaler.transform(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in transform(self, X)
#     506         check_is_fitted(self)
#     507
# --> 508         X = self._validate_data(
#     509             X,
#     510             copy=self.copy,
#
# ...

# %%
y_test.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-e953b55d249c> in <cell line: 1>()
# ----> 1 y_test.values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

# %%
model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 0s 2ms/step - loss: 421396545536.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 2ms/step - loss: 389882740736.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 2ms/step - loss: 258075607040.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 2ms/step - loss: 120921546752.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 2ms/step - loss: 103328276480.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 2ms/step - loss: 101110325248.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 2ms/step - loss: 98743853056.0000
# Epoch 8/400
# 119/119 [==============================] - 0s 2ms/step - loss: 96258424832.0000
# Epoch 9/400
# 119/119 [==============================] - 0s 2ms/step - loss: 93631307776.0000
# Epoch 10/400
# 119/119 [==============================] - 0s 2ms/step - loss: 90753900544.0000
# Epoch 11/400
# ...

# %%
model.history.history
# Out:
# {'loss': [421396545536.0,
#   389882740736.0,
#   258075607040.0,
#   120921546752.0,
#   103328276480.0,
#   101110325248.0,
#   98743853056.0,
#   96258424832.0,
#   93631307776.0,
#   90753900544.0,
#   87695966208.0,
#   84419526656.0,
#   80899637248.0,
#   77264420864.0,
#   73459187712.0,
#   69571158016.0,
#   65923457024.0,
#   62521921536.0,
#   59591954432.0,
#   57170817024.0,
#   55178833920.0,
#   53648285696.0,
#   52403798016.0,
#   51360272384.0,
#   50467287040.0,
#   49661554688.0,
#   48952016896.0,
#   48246259712.0,
#   47685505024.0,
#   47123664896.0,
#   46593347584.0,
#   46177779712.0,
#   45742809088.0,
#   45355769856.0,
#   44987420672.0,
#   44670132224.0,
#   44380676096.0,
#   44087078912.0,
#   43830312960.0,
#   43609886720.0,
#   43337134080.0,
#   43120893952.0,
#   42932654080.0,
#   42748260352.0,
#   42509885440.0,
#   42332647424.0,
#   42133827584.0,
#   41945145344.0,
#   41778495488.0,
#   41577320448.0,
#   41353957376.0,
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %%
X_test.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-fbd38763ea09> in <cell line: 1>()
# ----> 1 X_test.values
#
# AttributeError: 'MinMaxScaler' object has no attribute 'values'
